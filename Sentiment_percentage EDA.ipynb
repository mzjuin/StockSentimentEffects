# %%
import pymysql
import logging
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from ipywidgets import interact, interact_manual


# for stock_code in klci_stock_code:
klci_stock_code = [1155, 1295, 5183, 5347, 1023, 5225, 6012, 6888, 
                    5819, 6947, 5285, 4707, 6033, 3816, 1961, 4065, 
                    3182, 2445, 3034, 5681, 1066, 1082, 8869, 4715, 
                    7277, 5168, 4197, 1015, 7113, 5014]

# %%
def getData():
    '''Get data from database'''
    connection = pymysql.connect()

    query =''' '''

    df = pd.read_sql_query(query, connection)

    connection.close()
    return df

def calculateCorr(dataframe):
    '''Calculate the pearson correlation between positivity and percentage_change'''
    corr = dataframe[['positivity','percentage_change']].corr(method ='pearson')
    
    return corr.positivity[-1]

def normalize(dataframe):
    '''Normalize percentageChange into range of -1 to 1'''
    dataframe.percentage_change =(((dataframe.percentage_change-dataframe.percentage_change.min())/(dataframe.percentage_change.max()-dataframe.percentage_change.min()))*2) -1
    
    return dataframe.percentage_change

def lagBackward(dataframe, num_lag):
    '''Lag percentageChange column for num_lag(days) user provided'''
    
    dataframe.percentage_change.index = dataframe.percentage_change.index - num_lag
    df_corr2 = pd.concat([dataframe.positivity, dataframe.percentage_change, dataframe.trading_date], axis = 1)
    
    return df_corr2

# %%
# Get KLCI 30 stocks data
df = getData()
klci_stock_code = [str(x) for x in klci_stock_code]
df30 = df[df.stock_code_id.isin(klci_stock_code)]
print(df30.stock_code_id.nunique())

# Selecting stock 1155
# df2_1155 = df30[df30.stock_code_id == '1155']
# Out:
# 30

# %%
# Convert to date type
df30.trading_date = df30.trading_date.astype('datetime64[D]')
# Filter the date start from 2018-03-08
df30_2 = df30.query('trading_date > 20180308')

# %%
# Normalize percentage_change of each stock
for stock_code in klci_stock_code:
    df30_2.loc[df30_2.stock_code_id == stock_code, 'percentage_change'] = normalize(df30_2[df30_2.stock_code_id == stock_code])
    print(df30_2[df30_2.stock_code_id == stock_code].describe(), stock_code, '\n')
# Out:
# C:\Users\jugnu\Anaconda3\envs\py36\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Users\jugnu\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#        positivity     closing  price_change  percentage_change  total_article
# count  346.000000  260.000000    260.000000         260.000000     346.000000
# mean    -0.104628    9.634462     -0.004231           0.034401       9.465318
# std      0.338813    0.464313      0.091228           0.228822       6.207075
# min     -0.903707    8.680000     -0.430000          -1.000000       1.000000
# 25%     -0.326219    9.337500     -0.030000          -0.033981       4.000000
# 50%     -0.128122    9.540000      0.000000           0.043689       9.500000
# 75%      0.112740    9.810000      0.030000           0.118932      14.000000
# max      0.988743   10.880000      0.380000           1.000000      34.000000 1155
#
#        positivity     closing  price_change  percentage_change  total_article
# count  323.000000  261.000000    261.000000         261.000000     323.000000
# mean    -0.208529   24.229885     -0.000843          -0.050440       8.433437
# std      0.371770    0.841949      0.205383           0.218992       5.188173
# min     -0.911422   22.260000     -0.920000          -1.000000       1.000000
# 25%     -0.490530   23.940000     -0.040000          -0.093951       4.000000
# 50%     -0.260035   24.540000      0.000000          -0.050193       8.000000
# 75%      0.054355   24.900000      0.060000           0.011583      12.000000
# max      0.962166   25.320000      0.980000           1.000000      32.000000 1295
#
#        positivity     closing  price_change  percentage_change  total_article
# min     -0.933607    4.550000     -0.600000          -1.000000       1.000000
# 25%     -0.374849    5.705000     -0.065000           0.158416       1.000000
# 50%     -0.104198    6.150000      0.000000           0.292079       2.000000
# 75%      0.119241    6.340000      0.050000           0.406559       3.000000
# max      0.662040    7.280000      0.330000           1.000000      32.000000 5168
#
#        positivity     closing  price_change  percentage_change  total_article
# count  224.000000  184.000000    184.000000         184.000000     224.000000
# mean    -0.039352    2.437446     -0.002228           0.064005       2.183036
# std      0.385701    0.176029      0.047124           0.271028       1.867224
# min     -0.974700    2.100000     -0.210000          -1.000000       1.000000
# 25%     -0.235309    2.290000     -0.020000          -0.052613       1.000000
# 50%      0.039518    2.430000      0.000000           0.074859       2.000000
# 75%      0.189547    2.580000      0.020000           0.190678       3.000000
# max      0.977244    2.810000      0.150000           1.000000      12.000000 4197
#
#        positivity     closing  price_change  percentage_change  total_article
# count  273.000000  218.000000    218.000000         218.000000     273.000000
# mean    -0.028126    4.095000      0.003899           0.150559       2.857143
# std      0.346829    0.301107      0.060176           0.238629       2.530279
# min     -0.856928    3.450000     -0.270000          -1.000000       1.000000
# 25%     -0.255202    3.880000     -0.020000           0.050391       1.000000
# 50%     -0.027424    4.065000      0.000000           0.134375       2.000000
# 75%      0.189027    4.400000      0.030000           0.257422       4.000000
# max      0.978400    4.590000      0.240000           1.000000      22.000000 1015
#
#        positivity     closing  price_change  percentage_change  total_article
# count  249.000000  209.000000    209.000000         209.000000     249.000000
# mean    -0.111412    8.233062      0.002727           0.466035       3.670683
# std      0.304504    2.736265      0.273091           0.161270       3.759395
# min     -0.905246    4.320000     -2.970000          -1.000000       1.000000
# 25%     -0.301606    5.470000     -0.050000           0.418605       1.000000
# 50%     -0.064550    9.890000      0.000000           0.463924       2.000000
# 75%      0.102910   10.520000      0.100000           0.525939       4.000000
# max      0.741075   12.300000      0.980000           1.000000      24.000000 7113
#
#        positivity     closing  price_change  percentage_change  total_article
# count  307.000000  238.000000    238.000000         238.000000     307.000000
# mean     0.000072    8.390630     -0.005504           0.027408       4.609121
# std      0.288173    0.664317      0.135875           0.216560       4.378757
# min     -0.883623    6.610000     -0.640000          -1.000000       1.000000
# 25%     -0.146453    7.972500     -0.060000          -0.062708       1.500000
# 50%      0.051033    8.420000      0.000000           0.035357       3.000000
# 75%      0.173132    8.900000      0.060000           0.132422       6.000000
# max      0.821013    9.860000      0.550000           1.000000      26.000000 5014

# %%
# Fill NaN with 0
for stock_code in klci_stock_code:
    df30_2.loc[df30_2.stock_code_id == stock_code, 'percentage_change'] = df30_2.loc[df30_2.stock_code_id == stock_code, 'percentage_change'].fillna(0)
    print(df30_2[df30_2.stock_code_id == stock_code].info(), stock_code, '\n')
# Out:
# C:\Users\jugnu\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346 entries, 53 to 36878
# Data columns (total 7 columns):
# trading_date         346 non-null datetime64[ns]
# positivity           346 non-null float64
# closing              260 non-null float64
# price_change         260 non-null float64
# percentage_change    346 non-null float64
# total_article        346 non-null int64
# stock_code_id        346 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 21.6+ KB
# None 1155
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323 entries, 402 to 36782
# Data columns (total 7 columns):
# trading_date         323 non-null datetime64[ns]
# positivity           323 non-null float64
# closing              261 non-null float64
# price_change         261 non-null float64
# percentage_change    323 non-null float64
# total_article        323 non-null int64
# stock_code_id        323 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 20.2+ KB
# None 1295
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290 entries, 86 to 36825
# Data columns (total 7 columns):
# trading_date         290 non-null datetime64[ns]
# positivity           290 non-null float64
# closing              256 non-null float64
# price_change         256 non-null float64
# percentage_change    290 non-null float64
# total_article        290 non-null int64
# stock_code_id        290 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 18.1+ KB
# None 5183
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345 entries, 81 to 36885
# Data columns (total 7 columns):
# trading_date         345 non-null datetime64[ns]
# positivity           345 non-null float64
# closing              267 non-null float64
# price_change         267 non-null float64
# percentage_change    345 non-null float64
# total_article        345 non-null int64
# stock_code_id        345 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 21.6+ KB
# None 5347
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359 entries, 51 to 36776
# Data columns (total 7 columns):
# trading_date         359 non-null datetime64[ns]
# positivity           359 non-null float64
# closing              264 non-null float64
# price_change         264 non-null float64
# percentage_change    359 non-null float64
# total_article        359 non-null int64
# stock_code_id        359 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 22.4+ KB
# None 1023
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276 entries, 627 to 36830
# Data columns (total 7 columns):
# trading_date         276 non-null datetime64[ns]
# positivity           276 non-null float64
# closing              220 non-null float64
# price_change         220 non-null float64
# percentage_change    276 non-null float64
# total_article        276 non-null int64
# stock_code_id        276 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 17.2+ KB
# None 5225
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280 entries, 306 to 36804
# Data columns (total 7 columns):
# trading_date         280 non-null datetime64[ns]
# positivity           280 non-null float64
# closing              230 non-null float64
# price_change         230 non-null float64
# percentage_change    280 non-null float64
# total_article        280 non-null int64
# stock_code_id        280 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 17.5+ KB
# None 6012
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301 entries, 153 to 36865
# Data columns (total 7 columns):
# trading_date         301 non-null datetime64[ns]
# positivity           301 non-null float64
# closing              235 non-null float64
# price_change         235 non-null float64
# percentage_change    301 non-null float64
# total_article        301 non-null int64
# stock_code_id        301 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 18.8+ KB
# None 6888
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284 entries, 83 to 36801
# Data columns (total 7 columns):
# trading_date         284 non-null datetime64[ns]
# positivity           284 non-null float64
# closing              245 non-null float64
# price_change         245 non-null float64
# percentage_change    284 non-null float64
# total_article        284 non-null int64
# stock_code_id        284 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 17.8+ KB
# None 5819
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 456 to 36866
# Data columns (total 7 columns):
# trading_date         240 non-null datetime64[ns]
# positivity           240 non-null float64
# closing              201 non-null float64
# price_change         201 non-null float64
# percentage_change    240 non-null float64
# total_article        240 non-null int64
# stock_code_id        240 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 15.0+ KB
# None 6947
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 130 to 36798
# Data columns (total 7 columns):
# trading_date         175 non-null datetime64[ns]
# positivity           175 non-null float64
# closing              151 non-null float64
# price_change         151 non-null float64
# percentage_change    175 non-null float64
# total_article        175 non-null int64
# stock_code_id        175 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 10.9+ KB
# None 5285
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288 entries, 47 to 36844
# Data columns (total 7 columns):
# trading_date         288 non-null datetime64[ns]
# positivity           288 non-null float64
# closing              242 non-null float64
# price_change         242 non-null float64
# percentage_change    288 non-null float64
# total_article        288 non-null int64
# stock_code_id        288 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 18.0+ KB
# None 4707
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255 entries, 233 to 36805
# Data columns (total 7 columns):
# trading_date         255 non-null datetime64[ns]
# positivity           255 non-null float64
# closing              227 non-null float64
# price_change         227 non-null float64
# percentage_change    255 non-null float64
# total_article        255 non-null int64
# stock_code_id        255 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 15.9+ KB
# None 6033
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 199 to 36791
# Data columns (total 7 columns):
# trading_date         216 non-null datetime64[ns]
# positivity           216 non-null float64
# closing              183 non-null float64
# price_change         183 non-null float64
# percentage_change    216 non-null float64
# total_article        216 non-null int64
# stock_code_id        216 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 13.5+ KB
# None 3816
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248 entries, 859 to 36880
# Data columns (total 7 columns):
# trading_date         248 non-null datetime64[ns]
# positivity           248 non-null float64
# closing              206 non-null float64
# price_change         206 non-null float64
# percentage_change    248 non-null float64
# total_article        248 non-null int64
# stock_code_id        248 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 15.5+ KB
# None 1961
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 66 to 36794
# Data columns (total 7 columns):
# trading_date         236 non-null datetime64[ns]
# positivity           236 non-null float64
# closing              216 non-null float64
# price_change         216 non-null float64
# percentage_change    236 non-null float64
# total_article        236 non-null int64
# stock_code_id        236 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 14.8+ KB
# None 4065
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 195 to 36787
# Data columns (total 7 columns):
# trading_date         289 non-null datetime64[ns]
# positivity           289 non-null float64
# closing              235 non-null float64
# price_change         235 non-null float64
# percentage_change    289 non-null float64
# total_article        289 non-null int64
# stock_code_id        289 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 18.1+ KB
# None 3182
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 875 to 36667
# Data columns (total 7 columns):
# trading_date         168 non-null datetime64[ns]
# positivity           168 non-null float64
# closing              158 non-null float64
# price_change         158 non-null float64
# percentage_change    168 non-null float64
# total_article        168 non-null int64
# stock_code_id        168 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 10.5+ KB
# None 2445
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 137 to 36683
# Data columns (total 7 columns):
# trading_date         89 non-null datetime64[ns]
# positivity           89 non-null float64
# closing              80 non-null float64
# price_change         80 non-null float64
# percentage_change    89 non-null float64
# total_article        89 non-null int64
# stock_code_id        89 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 5.6+ KB
# None 3034
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 230 to 36800
# Data columns (total 7 columns):
# trading_date         250 non-null datetime64[ns]
# positivity           250 non-null float64
# closing              227 non-null float64
# price_change         227 non-null float64
# percentage_change    250 non-null float64
# total_article        250 non-null int64
# stock_code_id        250 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 15.6+ KB
# None 5681
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 321 entries, 52 to 36777
# Data columns (total 7 columns):
# trading_date         321 non-null datetime64[ns]
# positivity           321 non-null float64
# closing              264 non-null float64
# price_change         264 non-null float64
# percentage_change    321 non-null float64
# total_article        321 non-null int64
# stock_code_id        321 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 20.1+ KB
# None 1066
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215 entries, 258 to 36778
# Data columns (total 7 columns):
# trading_date         215 non-null datetime64[ns]
# positivity           215 non-null float64
# closing              196 non-null float64
# price_change         196 non-null float64
# percentage_change    215 non-null float64
# total_article        215 non-null int64
# stock_code_id        215 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 13.4+ KB
# None 1082
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 108 to 36003
# Data columns (total 7 columns):
# trading_date         149 non-null datetime64[ns]
# positivity           149 non-null float64
# closing              125 non-null float64
# price_change         125 non-null float64
# percentage_change    149 non-null float64
# total_article        149 non-null int64
# stock_code_id        149 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 9.3+ KB
# None 8869
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 113 to 36845
# Data columns (total 7 columns):
# trading_date         230 non-null datetime64[ns]
# positivity           230 non-null float64
# closing              192 non-null float64
# price_change         192 non-null float64
# percentage_change    230 non-null float64
# total_article        230 non-null int64
# stock_code_id        230 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 14.4+ KB
# None 4715
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 100 to 36834
# Data columns (total 7 columns):
# trading_date         235 non-null datetime64[ns]
# positivity           235 non-null float64
# closing              199 non-null float64
# price_change         199 non-null float64
# percentage_change    235 non-null float64
# total_article        235 non-null int64
# stock_code_id        235 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 14.7+ KB
# None 7277
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215 entries, 85 to 36520
# Data columns (total 7 columns):
# trading_date         215 non-null datetime64[ns]
# positivity           215 non-null float64
# closing              183 non-null float64
# price_change         183 non-null float64
# percentage_change    215 non-null float64
# total_article        215 non-null int64
# stock_code_id        215 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 13.4+ KB
# None 5168
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 224 entries, 67 to 36796
# Data columns (total 7 columns):
# trading_date         224 non-null datetime64[ns]
# positivity           224 non-null float64
# closing              184 non-null float64
# price_change         184 non-null float64
# percentage_change    224 non-null float64
# total_article        224 non-null int64
# stock_code_id        224 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 14.0+ KB
# None 4197
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273 entries, 122 to 36775
# Data columns (total 7 columns):
# trading_date         273 non-null datetime64[ns]
# positivity           273 non-null float64
# closing              218 non-null float64
# price_change         218 non-null float64
# percentage_change    273 non-null float64
# total_article        273 non-null int64
# stock_code_id        273 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 17.1+ KB
# None 1015
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 76 to 36719
# Data columns (total 7 columns):
# trading_date         249 non-null datetime64[ns]
# positivity           249 non-null float64
# closing              209 non-null float64
# price_change         209 non-null float64
# percentage_change    249 non-null float64
# total_article        249 non-null int64
# stock_code_id        249 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 15.6+ KB
# None 7113
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 49 to 36860
# Data columns (total 7 columns):
# trading_date         307 non-null datetime64[ns]
# positivity           307 non-null float64
# closing              238 non-null float64
# price_change         238 non-null float64
# percentage_change    307 non-null float64
# total_article        307 non-null int64
# stock_code_id        307 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 19.2+ KB
# None 5014

# %%
sentiment_percentageChange = []
print("Sentiment-Percentage Change")
for stock_code in klci_stock_code:
    correlation = df30_2[df30_2.stock_code_id == stock_code][['positivity','percentage_change']].corr()
    print("Stock :", stock_code ," Correlation : ", round(correlation.positivity[-1],3))
    sentiment_percentageChange.append((stock_code, round(correlation.positivity[-1])))
# Out:
# Sentiment-Percentage Change
# Stock : 1155  Correlation :  0.233
# Stock : 1295  Correlation :  0.235
# Stock : 5183  Correlation :  0.254
# Stock : 5347  Correlation :  0.314
# Stock : 1023  Correlation :  0.232
# Stock : 5225  Correlation :  0.23
# Stock : 6012  Correlation :  0.255
# Stock : 6888  Correlation :  0.261
# Stock : 5819  Correlation :  0.141
# Stock : 6947  Correlation :  0.289
# Stock : 5285  Correlation :  0.201
# Stock : 4707  Correlation :  0.146
# Stock : 6033  Correlation :  0.245
# Stock : 3816  Correlation :  0.066
# Stock : 1961  Correlation :  0.153
# Stock : 4065  Correlation :  0.217
# Stock : 3182  Correlation :  0.206
# Stock : 2445  Correlation :  0.137
# Stock : 3034  Correlation :  -0.062
# Stock : 5681  Correlation :  0.16
# Stock : 1066  Correlation :  0.148
# Stock : 1082  Correlation :  0.19
# Stock : 8869  Correlation :  0.123
# Stock : 4715  Correlation :  0.193
# Stock : 7277  Correlation :  0.174
# Stock : 5168  Correlation :  0.09
# Stock : 4197  Correlation :  0.262
# Stock : 1015  Correlation :  0.169
# Stock : 7113  Correlation :  0.133
# Stock : 5014  Correlation :  0.134
